# %% [markdown]
# # Configuring the Logging Output for TARDIS

# %% [markdown]
# **TARDIS** has a Notebook logger that logs information of Simulation runs. The logs allows to access vital information regarding the execution sequence, data for plasma stratification & progress of the simulation.<br>
# **TARDIS** allows configuring the logger via *Functional Arguments* as well as *YAML Parameters*.
# The following code snippets are some of the possible configuration that is available for the notebook logging done with TARDIS simulation.

# %% [markdown]
# ## Default Configuration

# %% [markdown]
# The default configuration of the Notebook Simulation logger is such that it doesn't output any logs.

# %% [markdown]
# The output simulation logging, while executing the **TARDIS** simulation (default behaviour), can be seen below:

# %%
from tardis import run_tardis
from tardis.io.atom_data.util import download_atom_data
# Out:
# /usr/share/miniconda3/envs/tardis/lib/python3.7/importlib/_bootstrap.py:219: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)

# %%
download_atom_data('kurucz_cd23_chianti_H_He')
# Out:
# [tardis.io.atom_data.atom_web_download][INFO   ]  Downloading atomic data from https://media.githubusercontent.com/media/tardis-sn/tardis-refdata/master/atom_data/kurucz_cd23_chianti_H_He.h5 to /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (atom_web_download.py:46)

# %%
sim = run_tardis("tardis_config_logger.yml")
# Out:
# [py.warnings         ][WARNING]  /usr/share/miniconda3/envs/tardis/lib/python3.7/site-packages/traitlets/traitlets.py:3036: FutureWarning: --rc={'figure.dpi': 96} for dict-traits is deprecated in traitlets 5.0. You can pass --rc <key=value> ... multiple times to add items to a dict.
#   FutureWarning,
#  (warnings.py:110)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': 'b15b41f1-1bbd-46d4-9e7b-59a146a7f75e', …

# %% [markdown]
# It can be examined that the logs are not printed.<br> The logging level, by default, is set to `CRITICAL`. Logs will only be captured if any `CRITICAL` level logs are encountered while running the simulation.

# %% [markdown]
# ## Logging Configuration (Functional Arguments)

# %% [markdown]
# The `run_tardis()` function from the `tardis module` has two functional arguments:`log_state` & `specific`.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     Both <strong>log_state</strong> & <strong>specific</strong> are optional arguments for the <strong>run_tardis()</strong> function, however, if <strong>specific</strong> argument is used then, <strong>log_state</strong> must be set to a particular level.
# </div>

# %% [markdown]
# ### `log_state`

# %% [markdown]
# The `log_state` argument can be passed in `run_tardis()` to set the logging level for the simulation. The input for this argument **must be** one of the following: **Notset, Debug, Info, Warning, Error** or **Critical**.

# %%
sim = run_tardis("tardis_config_logger.yml", log_state="Info")
# Out:
# log_state is defined both in Functional Argument & YAML Configuration {debug section}
# log_state = INFO will be used for Log Level Determination
#
# [tardis.plasma.standard_plasmas][INFO   ]
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:91)
# [tardis.io.atom_data.util][INFO   ]
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with:
# 	UUID = 6f7b09e887a311e7a06b246e96350010
# 	MD5  = 864f1753714343c41f99cb065710cace  (base.py:189)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided atomic data:
# 	synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:193)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 1 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_a97e9e8c_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a97e9e8c_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >9.93e+03</td>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.4</td>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.481</td>
#             </tr>
#             <tr>
#                         <th id="T_a97e9e8c_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >9.85e+03</td>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.03e+04</td>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.211</td>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.193</td>
#             </tr>
#             <tr>
#                         <th id="T_a97e9e8c_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >9.78e+03</td>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.02e+04</td>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.143</td>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.112</td>
#             </tr>
#             <tr>
#                         <th id="T_a97e9e8c_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >9.71e+03</td>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >9.98e+03</td>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.105</td>
#                         <td id="T_a97e9e8c_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0826</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:518)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '94488f15-27f3-4930-b64c-1796f5cf8baf', …
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 2 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_a9b26082_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a9b26082_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.15e+04</td>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.481</td>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.555</td>
#             </tr>
#             <tr>
#                         <th id="T_a9b26082_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.03e+04</td>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.17e+04</td>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.193</td>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.203</td>
#             </tr>
#             <tr>
#                         <th id="T_a9b26082_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.02e+04</td>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.13e+04</td>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.112</td>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.135</td>
#             </tr>
#             <tr>
#                         <th id="T_a9b26082_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >9.98e+03</td>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0826</td>
#                         <td id="T_a9b26082_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0998</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:518)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 3 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_a9c90d3c_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a9c90d3c_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.15e+04</td>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.555</td>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.468</td>
#             </tr>
#             <tr>
#                         <th id="T_a9c90d3c_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.17e+04</td>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.05e+04</td>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.203</td>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.181</td>
#             </tr>
#             <tr>
#                         <th id="T_a9c90d3c_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.13e+04</td>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.05e+04</td>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.135</td>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.108</td>
#             </tr>
#             <tr>
#                         <th id="T_a9c90d3c_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >1.1e+04</td>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.03e+04</td>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0998</td>
#                         <td id="T_a9c90d3c_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0779</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:518)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 4 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_a9dfffd8_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a9dfffd8_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.14e+04</td>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.468</td>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.527</td>
#             </tr>
#             <tr>
#                         <th id="T_a9dfffd8_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.05e+04</td>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.13e+04</td>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.181</td>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.225</td>
#             </tr>
#             <tr>
#                         <th id="T_a9dfffd8_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.05e+04</td>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.12e+04</td>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.108</td>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.126</td>
#             </tr>
#             <tr>
#                         <th id="T_a9dfffd8_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >1.03e+04</td>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0779</td>
#                         <td id="T_a9dfffd8_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0926</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:518)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 5 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Simulation finished in 5 iterations
# 	Simulation took 1.28 s
#  (base.py:444)

# %% [markdown]
# By setting up the `log_state` parameter to **"Info"** in the above example, we can check that the logs are at the **"Info"** or higher logging level.

# %% [markdown]
# ### `specific`

# %% [markdown]
# The `specific` argument tells the logger to capture log messages set by the `log_state` parameter. It can only take *Boolean* values for input, which are `True` or `False`. Take for example the following:

# %%
sim = run_tardis("tardis_config_logger.yml", log_state="Debug", specific=True)
# Out:
# log_state is defined both in Functional Argument & YAML Configuration {debug section}
# log_state = DEBUG will be used for Log Level Determination
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.montecarlo.base][DEBUG  ]  Electron scattering switched on (base.py:576)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '9e4f01bf-efc7-4b79-8796-2e83982e13a8', …
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)

# %% [markdown]
# It can be examined that, when we set `specific` to `True`, the log messages captured were only at the `DEBUG` log level.<br> This allows for logging only specified logging messages for inspection.

# %% [markdown]
# The changes in the captured log messages can be seen when we set `specific` to `False`.

# %%
sim = run_tardis("tardis_config_logger.yml", log_state="Debug", specific=False)
# Out:
# log_state is defined both in Functional Argument & YAML Configuration {debug section}
# log_state = DEBUG will be used for Log Level Determination
#
# [tardis.plasma.standard_plasmas][INFO   ]
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:91)
# [tardis.io.atom_data.util][INFO   ]
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with:
# 	UUID = 6f7b09e887a311e7a06b246e96350010
# 	MD5  = 864f1753714343c41f99cb065710cace  (base.py:189)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided atomic data:
# 	synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:193)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.montecarlo.base][DEBUG  ]  Electron scattering switched on (base.py:576)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 1 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_add5c938_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_add5c938_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >9.93e+03</td>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.4</td>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.481</td>
#             </tr>
#             <tr>
#                         <th id="T_add5c938_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >9.85e+03</td>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.03e+04</td>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.211</td>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.193</td>
#             </tr>
#             <tr>
#                         <th id="T_add5c938_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >9.78e+03</td>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.02e+04</td>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.143</td>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.112</td>
#             </tr>
#             <tr>
#                         <th id="T_add5c938_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >9.71e+03</td>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >9.98e+03</td>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.105</td>
#                         <td id="T_add5c938_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0826</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:518)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '4ab761f0-a18d-4283-a662-1582c9737f56', …
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 2 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_ae05d4a2_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ae05d4a2_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.15e+04</td>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.481</td>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.555</td>
#             </tr>
#             <tr>
#                         <th id="T_ae05d4a2_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.03e+04</td>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.17e+04</td>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.193</td>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.203</td>
#             </tr>
#             <tr>
#                         <th id="T_ae05d4a2_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.02e+04</td>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.13e+04</td>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.112</td>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.135</td>
#             </tr>
#             <tr>
#                         <th id="T_ae05d4a2_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >9.98e+03</td>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0826</td>
#                         <td id="T_ae05d4a2_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0998</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:518)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 3 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_ae1c8224_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ae1c8224_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.15e+04</td>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.555</td>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.468</td>
#             </tr>
#             <tr>
#                         <th id="T_ae1c8224_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.17e+04</td>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.05e+04</td>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.203</td>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.181</td>
#             </tr>
#             <tr>
#                         <th id="T_ae1c8224_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.13e+04</td>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.05e+04</td>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.135</td>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.108</td>
#             </tr>
#             <tr>
#                         <th id="T_ae1c8224_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >1.1e+04</td>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.03e+04</td>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0998</td>
#                         <td id="T_ae1c8224_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0779</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:518)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 4 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_ae333be0_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ae333be0_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.14e+04</td>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.468</td>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.527</td>
#             </tr>
#             <tr>
#                         <th id="T_ae333be0_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.05e+04</td>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.13e+04</td>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.181</td>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.225</td>
#             </tr>
#             <tr>
#                         <th id="T_ae333be0_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.05e+04</td>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.12e+04</td>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.108</td>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.126</td>
#             </tr>
#             <tr>
#                         <th id="T_ae333be0_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >1.03e+04</td>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0779</td>
#                         <td id="T_ae333be0_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0926</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:518)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 5 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Simulation finished in 5 iterations
# 	Simulation took 1.19 s
#  (base.py:444)

# %% [markdown]
# It can be examined in this example that when we kept `specific` to `False`, the captured log output includes all log messages from `DEBUG` and higher logging levels, which is the default behavior of the logger.

# %% [markdown]
# ## Logging Configuration (YAML Configuration)

# %% [markdown]
# The behavior of the logging output for the simulation can be configured via the `tardis_config_logger.yml` *(**YAML** Configuration)* file. For setting up the logger via the YAML file, the configuration file must include a `debug` section. An example configuration for the `debug` section can be seen below:

# %% [markdown]
# ```YAML
# ...
# debug:
#   log_state: "Info"
#   specific : False
# ```

# %% [markdown]
# The `debug` schema includes the `log_state` & `specific` parameters.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     The <strong>debug</strong> section of the <strong>YAML</strong> config file is <i>optional</i>. The <strong>log_state</strong> and the <strong>specific</strong> arguments are <i>optional</i> as well. If none of the parameters are defined, then the values of these parameter fall back on the <strong>default values</strong>.
# </div>

# %% [markdown]
# Let us load the `tardis_config_logger.yml` configuration to a variable & check out the schema:

# %%
from tardis.io.config_reader import Configuration

# %%
# Loading the Schema 
config = Configuration.from_yaml("tardis_config_logger.yml")

# Checking the Debug Schema via dictionary
config["debug"]
# Out:
# {'specific': False, 'log_state': 'Critical'}

# %% [markdown]
# ### `log_state`

# %% [markdown]
# The `log_state` parameter, in the `debug` section of the config file, is similar in functionality to the `log_state` functional argument that can be passed via the `run_tardis()` function. The value of this parameter **must be** one of the following: **Notset, Debug, Info, Warning, Error** or **Critical**.

# %% [markdown]
# Let us see an example of the captured simulation logging output, when the `log_state` parameter is set to `"Info"` log level in the `tardis_config_logger.yml` config file.

# %%
config["debug"]["log_state"] = "Info"

# %%
# Running the simulation by passing the config dictionary to `run_tardis()` function
sim = run_tardis(config)
# Out:
# [tardis.plasma.standard_plasmas][INFO   ]
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:91)
# [tardis.io.atom_data.util][INFO   ]
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with:
# 	UUID = 6f7b09e887a311e7a06b246e96350010
# 	MD5  = 864f1753714343c41f99cb065710cace  (base.py:189)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided atomic data:
# 	synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:193)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 1 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b00c7058_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b00c7058_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >9.93e+03</td>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.4</td>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.481</td>
#             </tr>
#             <tr>
#                         <th id="T_b00c7058_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >9.85e+03</td>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.03e+04</td>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.211</td>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.193</td>
#             </tr>
#             <tr>
#                         <th id="T_b00c7058_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >9.78e+03</td>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.02e+04</td>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.143</td>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.112</td>
#             </tr>
#             <tr>
#                         <th id="T_b00c7058_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >9.71e+03</td>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >9.98e+03</td>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.105</td>
#                         <td id="T_b00c7058_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0826</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:518)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': 'ad220f48-5657-4318-9784-1dac284abde7', …
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 2 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b03e28fa_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b03e28fa_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.15e+04</td>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.481</td>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.555</td>
#             </tr>
#             <tr>
#                         <th id="T_b03e28fa_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.03e+04</td>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.17e+04</td>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.193</td>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.203</td>
#             </tr>
#             <tr>
#                         <th id="T_b03e28fa_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.02e+04</td>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.13e+04</td>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.112</td>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.135</td>
#             </tr>
#             <tr>
#                         <th id="T_b03e28fa_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >9.98e+03</td>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0826</td>
#                         <td id="T_b03e28fa_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0998</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:518)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 3 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b055848c_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b055848c_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.15e+04</td>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.555</td>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.468</td>
#             </tr>
#             <tr>
#                         <th id="T_b055848c_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.17e+04</td>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.05e+04</td>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.203</td>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.181</td>
#             </tr>
#             <tr>
#                         <th id="T_b055848c_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.13e+04</td>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.05e+04</td>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.135</td>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.108</td>
#             </tr>
#             <tr>
#                         <th id="T_b055848c_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >1.1e+04</td>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.03e+04</td>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0998</td>
#                         <td id="T_b055848c_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0779</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:518)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 4 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b06b4b46_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b06b4b46_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.14e+04</td>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.468</td>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.527</td>
#             </tr>
#             <tr>
#                         <th id="T_b06b4b46_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.05e+04</td>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.13e+04</td>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.181</td>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.225</td>
#             </tr>
#             <tr>
#                         <th id="T_b06b4b46_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.05e+04</td>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.12e+04</td>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.108</td>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.126</td>
#             </tr>
#             <tr>
#                         <th id="T_b06b4b46_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >1.03e+04</td>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0779</td>
#                         <td id="T_b06b4b46_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0926</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:518)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 5 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Simulation finished in 5 iterations
# 	Simulation took 1.18 s
#  (base.py:444)

# %% [markdown]
# ### `specific`

# %% [markdown]
# The `specific` parameter in the `debug` section of the schema is similar in functionality to the `specific` functional argument. It takes **Boolean** values, i.e., `True` or `False`. It is an optional parameter.

# %% [markdown]
# Let us see an example when we set `specific` to `True` at the `Debug` level.

# %%
config["debug"]["log_state"] = "Debug"
config["debug"]["specific"] = True

# %%
sim = run_tardis(config)
# Out:
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.montecarlo.base][DEBUG  ]  Electron scattering switched on (base.py:576)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': 'ad7c0006-3641-4d4d-8e2b-51443cfbad61', …
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)

# %% [markdown]
# Setting `specific` to `False` to check the actual output at the `DEBUG` level for the simulation logs.

# %%
config["debug"]["specific"] = False

# %%
sim = run_tardis(config)
# Out:
# [tardis.plasma.standard_plasmas][INFO   ]
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:91)
# [tardis.io.atom_data.util][INFO   ]
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with:
# 	UUID = 6f7b09e887a311e7a06b246e96350010
# 	MD5  = 864f1753714343c41f99cb065710cace  (base.py:189)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided atomic data:
# 	synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:193)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: SelectedAtoms->IonizationData->AtomicMass->NumberDensity->Lines->Levels->LinesUpperLevelIndex->LinesLowerLevelIndex->JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.montecarlo.base][DEBUG  ]  Electron scattering switched on (base.py:576)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 1 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b43ccfec_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b43ccfec_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >9.93e+03</td>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.4</td>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.481</td>
#             </tr>
#             <tr>
#                         <th id="T_b43ccfec_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >9.85e+03</td>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.03e+04</td>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.211</td>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.193</td>
#             </tr>
#             <tr>
#                         <th id="T_b43ccfec_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >9.78e+03</td>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.02e+04</td>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.143</td>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.112</td>
#             </tr>
#             <tr>
#                         <th id="T_b43ccfec_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >9.71e+03</td>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >9.98e+03</td>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.105</td>
#                         <td id="T_b43ccfec_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0826</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:518)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '8d8c1e69-f1f7-4f2a-8016-83d29b74527a', …
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 2 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b46d147c_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b46d147c_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.15e+04</td>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.481</td>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.555</td>
#             </tr>
#             <tr>
#                         <th id="T_b46d147c_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.03e+04</td>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.17e+04</td>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.193</td>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.203</td>
#             </tr>
#             <tr>
#                         <th id="T_b46d147c_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.02e+04</td>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.13e+04</td>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.112</td>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.135</td>
#             </tr>
#             <tr>
#                         <th id="T_b46d147c_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >9.98e+03</td>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0826</td>
#                         <td id="T_b46d147c_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0998</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:518)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 3 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b48537f0_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b48537f0_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.15e+04</td>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.555</td>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.468</td>
#             </tr>
#             <tr>
#                         <th id="T_b48537f0_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.17e+04</td>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.05e+04</td>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.203</td>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.181</td>
#             </tr>
#             <tr>
#                         <th id="T_b48537f0_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.13e+04</td>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.05e+04</td>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.135</td>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.108</td>
#             </tr>
#             <tr>
#                         <th id="T_b48537f0_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >1.1e+04</td>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.03e+04</td>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0998</td>
#                         <td id="T_b48537f0_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0779</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:518)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 4 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b49c65f6_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b49c65f6_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.14e+04</td>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.468</td>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.527</td>
#             </tr>
#             <tr>
#                         <th id="T_b49c65f6_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.05e+04</td>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.13e+04</td>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.181</td>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.225</td>
#             </tr>
#             <tr>
#                         <th id="T_b49c65f6_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.05e+04</td>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.12e+04</td>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.108</td>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.126</td>
#             </tr>
#             <tr>
#                         <th id="T_b49c65f6_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >1.03e+04</td>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0779</td>
#                         <td id="T_b49c65f6_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0926</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:518)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order: JBluesDiluteBlackBody->ElectronTemperature->BetaRadiation->LevelBoltzmannFactorLTE->LevelBoltzmannFactorNoNLTE->PartitionFunction->GElectron->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:267)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 5 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Simulation finished in 5 iterations
# 	Simulation took 1.19 s
#  (base.py:444)

# %% [markdown]
# ### What Happens When Both Parameters Are Specified? { Function & YAML Arguments }

# %% [markdown]
# If a user specifies both the parameters passed through the `log_state` & `log_state` in the **YAML** configuration file, then the `log_state` parameter *(Functional Argument)* takes precedence & is used to determine the logging level for the simulation logs.

# %% [markdown]
# Let us consider the following example for the configuration:

# %% [markdown]
# Continuing from the previous example, the `config["debug"]["log_state"]` is set to `Debug` via the **YAML** file. The user will also set the `log_state` {Functional Argument} to `Info`.

# %%
sim = run_tardis(config, log_state = "Info")
# Out:
# log_state is defined both in Functional Argument & YAML Configuration {debug section}
# log_state = INFO will be used for Log Level Determination
#
# [tardis.plasma.standard_plasmas][INFO   ]
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:91)
# [tardis.io.atom_data.util][INFO   ]
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with:
# 	UUID = 6f7b09e887a311e7a06b246e96350010
# 	MD5  = 864f1753714343c41f99cb065710cace  (base.py:189)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided atomic data:
# 	synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:193)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 1 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b652f7e8_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b652f7e8_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >9.93e+03</td>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.4</td>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.481</td>
#             </tr>
#             <tr>
#                         <th id="T_b652f7e8_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >9.85e+03</td>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.03e+04</td>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.211</td>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.193</td>
#             </tr>
#             <tr>
#                         <th id="T_b652f7e8_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >9.78e+03</td>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.02e+04</td>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.143</td>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.112</td>
#             </tr>
#             <tr>
#                         <th id="T_b652f7e8_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >9.71e+03</td>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >9.98e+03</td>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.105</td>
#                         <td id="T_b652f7e8_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0826</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:518)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': 'a9d9fb5c-bc2a-406f-bffb-28e65cfee67b', …
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 2 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b6858104_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6858104_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.15e+04</td>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.481</td>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.555</td>
#             </tr>
#             <tr>
#                         <th id="T_b6858104_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.03e+04</td>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.17e+04</td>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.193</td>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.203</td>
#             </tr>
#             <tr>
#                         <th id="T_b6858104_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.02e+04</td>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.13e+04</td>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.112</td>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.135</td>
#             </tr>
#             <tr>
#                         <th id="T_b6858104_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >9.98e+03</td>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0826</td>
#                         <td id="T_b6858104_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0998</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:518)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 3 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b69c04ec_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b69c04ec_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.15e+04</td>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.555</td>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.468</td>
#             </tr>
#             <tr>
#                         <th id="T_b69c04ec_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.17e+04</td>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.05e+04</td>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.203</td>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.181</td>
#             </tr>
#             <tr>
#                         <th id="T_b69c04ec_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.13e+04</td>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.05e+04</td>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.135</td>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.108</td>
#             </tr>
#             <tr>
#                         <th id="T_b69c04ec_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >1.1e+04</td>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.03e+04</td>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0998</td>
#                         <td id="T_b69c04ec_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0779</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:518)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 4 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b6b29072_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6b29072_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.14e+04</td>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.468</td>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.527</td>
#             </tr>
#             <tr>
#                         <th id="T_b6b29072_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.05e+04</td>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.13e+04</td>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.181</td>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.225</td>
#             </tr>
#             <tr>
#                         <th id="T_b6b29072_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.05e+04</td>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.12e+04</td>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.108</td>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.126</td>
#             </tr>
#             <tr>
#                         <th id="T_b6b29072_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >1.03e+04</td>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0779</td>
#                         <td id="T_b6b29072_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0926</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:518)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 5 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Simulation finished in 5 iterations
# 	Simulation took 1.19 s
#  (base.py:444)

# %% [markdown]
# A new message can be seen from the execution of the simulation,
# ```
# log_state is defined both in Functional Argument & YAML Configuration {debug section}
# log_state = Info will be used for Log Level Determination
# ```
# that is informing the user which input log level value will determine the logging level. Thus, `log_state = "Info"` is used for logging the simulation output.

# %% [markdown]
# In regards to the `specific` parameter, if any of the config input value is `True`, then `specific` will be set to `True` for the simulation output.

# %%
sim = run_tardis(config, log_state = "Info", specific = True)
# Out:
# log_state is defined both in Functional Argument & YAML Configuration {debug section}
# log_state = INFO will be used for Log Level Determination
#
# [tardis.plasma.standard_plasmas][INFO   ]
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:91)
# [tardis.io.atom_data.util][INFO   ]
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with:
# 	UUID = 6f7b09e887a311e7a06b246e96350010
# 	MD5  = 864f1753714343c41f99cb065710cace  (base.py:189)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided atomic data:
# 	synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:193)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 1 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b8685dc0_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b8685dc0_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >9.93e+03</td>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.4</td>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.481</td>
#             </tr>
#             <tr>
#                         <th id="T_b8685dc0_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >9.85e+03</td>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.03e+04</td>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.211</td>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.193</td>
#             </tr>
#             <tr>
#                         <th id="T_b8685dc0_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >9.78e+03</td>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.02e+04</td>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.143</td>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.112</td>
#             </tr>
#             <tr>
#                         <th id="T_b8685dc0_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >9.71e+03</td>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >9.98e+03</td>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.105</td>
#                         <td id="T_b8685dc0_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0826</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:518)
# VBox(children=(FigureWidget({
#     'data': [{'type': 'scatter', 'uid': '8b905161-f3d3-4079-a7de-e2586eac6b23', …
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 2 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b899804e_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b899804e_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.15e+04</td>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.481</td>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.555</td>
#             </tr>
#             <tr>
#                         <th id="T_b899804e_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.03e+04</td>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.17e+04</td>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.193</td>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.203</td>
#             </tr>
#             <tr>
#                         <th id="T_b899804e_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.02e+04</td>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.13e+04</td>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.112</td>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.135</td>
#             </tr>
#             <tr>
#                         <th id="T_b899804e_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >9.98e+03</td>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0826</td>
#                         <td id="T_b899804e_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0998</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:518)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 3 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b8b03af0_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b8b03af0_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.15e+04</td>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.03e+04</td>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.555</td>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.468</td>
#             </tr>
#             <tr>
#                         <th id="T_b8b03af0_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.17e+04</td>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.05e+04</td>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.203</td>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.181</td>
#             </tr>
#             <tr>
#                         <th id="T_b8b03af0_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.13e+04</td>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.05e+04</td>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.135</td>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.108</td>
#             </tr>
#             <tr>
#                         <th id="T_b8b03af0_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >1.1e+04</td>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.03e+04</td>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0998</td>
#                         <td id="T_b8b03af0_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0779</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:518)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 4 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Plasma stratification: (base.py:490)
# <style  type="text/css" >
# </style><table id="T_b8c64d9a_deea_11eb_af99_000d3a436a11" ><thead>    <tr>        <th class="index_name level0" >Shell No.</th>        <th class="col_heading level0 col0" >t_rad</th>        <th class="col_heading level0 col1" >next_t_rad</th>        <th class="col_heading level0 col2" >w</th>        <th class="col_heading level0 col3" >next_w</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b8c64d9a_deea_11eb_af99_000d3a436a11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row0_col0" class="data row0 col0" >1.03e+04</td>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row0_col1" class="data row0 col1" >1.14e+04</td>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row0_col2" class="data row0 col2" >0.468</td>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row0_col3" class="data row0 col3" >0.527</td>
#             </tr>
#             <tr>
#                         <th id="T_b8c64d9a_deea_11eb_af99_000d3a436a11level0_row1" class="row_heading level0 row1" >5</th>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row1_col0" class="data row1 col0" >1.05e+04</td>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row1_col1" class="data row1 col1" >1.13e+04</td>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row1_col2" class="data row1 col2" >0.181</td>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row1_col3" class="data row1 col3" >0.225</td>
#             </tr>
#             <tr>
#                         <th id="T_b8c64d9a_deea_11eb_af99_000d3a436a11level0_row2" class="row_heading level0 row2" >10</th>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row2_col0" class="data row2 col0" >1.05e+04</td>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row2_col1" class="data row2 col1" >1.12e+04</td>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row2_col2" class="data row2 col2" >0.108</td>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row2_col3" class="data row2 col3" >0.126</td>
#             </tr>
#             <tr>
#                         <th id="T_b8c64d9a_deea_11eb_af99_000d3a436a11level0_row3" class="row_heading level0 row3" >15</th>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row3_col0" class="data row3 col0" >1.03e+04</td>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row3_col1" class="data row3 col1" >1.1e+04</td>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row3_col2" class="data row3 col2" >0.0779</td>
#                         <td id="T_b8c64d9a_deea_11eb_af99_000d3a436a11row3_col3" class="data row3 col3" >0.0926</td>
#             </tr>
#     </tbody></table>
# [tardis.simulation.base][INFO   ]
# 	Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:518)
# [tardis.simulation.base][INFO   ]
# 	Starting iteration 5 of 5 (base.py:359)
# [tardis.simulation.base][INFO   ]
# 	Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:523)
# [tardis.simulation.base][INFO   ]
# 	Simulation finished in 5 iterations
# 	Simulation took 1.17 s
#  (base.py:444)
